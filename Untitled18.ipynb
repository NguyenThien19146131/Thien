# %%
import matplotlib.pyplot as plt
from matplotlib.image import imread

folder = '/content/fruit data/'
for i in range(9):
  plt.subplot(330 + i +1)
  filename = folder + 'Banana (' + str(i + 1) + ').jpg'
  image = imread(filename)
  plt.imshow(image)
plt.show()

# %%
from os import listdir
from numpy import asarray
from numpy import save
from keras.preprocessing.image import load_img, img_to_array

folder = '/content/fruit data/'

photos, labels = list(), list()
for file in listdir(folder):
  if file.startswith('apple'):
    output = 0

  elif file.startswith('avacado'):
    output = 1

  elif file.startswith('Banana'):
    output = 2

  elif file.startswith('cherry'):
    output = 3

  elif file.startswith('nhan'):
    output = 4

  elif file.startswith('orange'):
    output = 5

  elif file.startswith('peach'):
    output = 6

  elif file.startswith('pinapple'):
    output = 7

  elif file.startswith('strawberry'):
    output = 8
    
  elif file.startswith('Grape'):
    output = 9
  photo = load_img(folder + file, target_size=(200,200))
  photo = img_to_array(photo)
  photos.append(photo)
  labels.append(output)


photos = asarray(photos)
labels = asarray(labels)
print(photos.shape, labels.shape)
# Out:
# (117, 200, 200, 3) (117,)

# %%
from keras.models import Sequential
from keras.layers import Dense, Activation, BatchNormalization, Dropout, Conv2D, MaxPool2D, Flatten 
from tensorflow.keras.optimizers import SGD

model = Sequential()
model.add(Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same', input_shape=(200,200, 3)))
model.add(MaxPool2D((2, 2)))

model.add(Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPool2D((2, 2)))

model.add(Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_uniform', padding='same'))
model.add(MaxPool2D((2, 2)))
model.add(Flatten())

model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(10, activation='softmax'))

# %%
model.compile(optimizer='Adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

history = model.fit(photos, labels, batch_size=64,epochs=20, verbose=1)
# Out:
# Epoch 1/20
# 2/2 [==============================] - 10s 4s/step - loss: 1091.4794 - accuracy: 0.0684
# Epoch 2/20
# 2/2 [==============================] - 9s 4s/step - loss: 1803.3965 - accuracy: 0.1026
# Epoch 3/20
# 2/2 [==============================] - 9s 4s/step - loss: 312.2192 - accuracy: 0.2393
# Epoch 4/20
# 2/2 [==============================] - 9s 4s/step - loss: 81.3956 - accuracy: 0.2137
# Epoch 5/20
# 2/2 [==============================] - 9s 4s/step - loss: 24.6184 - accuracy: 0.1966
# Epoch 6/20
# 2/2 [==============================] - 9s 4s/step - loss: 2.9321 - accuracy: 0.4103
# Epoch 7/20
# 2/2 [==============================] - 10s 4s/step - loss: 1.7497 - accuracy: 0.4957
# Epoch 8/20
# 2/2 [==============================] - 9s 4s/step - loss: 1.1994 - accuracy: 0.6154
# Epoch 9/20
# 2/2 [==============================] - 9s 4s/step - loss: 0.6959 - accuracy: 0.8291
# Epoch 10/20
# 2/2 [==============================] - 9s 4s/step - loss: 0.6892 - accuracy: 0.7521
# Epoch 11/20
# 2/2 [==============================] - 9s 4s/step - loss: 0.1662 - accuracy: 0.9402
# Epoch 12/20
# 2/2 [==============================] - 9s 4s/step - loss: 0.1855 - accuracy: 0.9231
# Epoch 13/20
# 2/2 [==============================] - 9s 4s/step - loss: 0.0497 - accuracy: 0.9915
# Epoch 14/20
# 2/2 [==============================] - 9s 4s/step - loss: 0.0242 - accuracy: 0.9915
# Epoch 15/20
# 2/2 [==============================] - 9s 4s/step - loss: 0.0178 - accuracy: 0.9915
# Epoch 16/20
# 2/2 [==============================] - 9s 4s/step - loss: 0.0909 - accuracy: 0.9829
# Epoch 17/20
# 2/2 [==============================] - 9s 4s/step - loss: 0.0062 - accuracy: 1.0000
# Epoch 18/20
# 2/2 [==============================] - 9s 4s/step - loss: 0.0112 - accuracy: 1.0000
# Epoch 19/20
# 2/2 [==============================] - 9s 4s/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 20/20
# 2/2 [==============================] - 9s 4s/step - loss: 0.0023 - accuracy: 1.0000

# %%
model.save('Fruits_Model.h5')

# %%
import matplotlib.pyplot as plt
from tensorflow.keras.utils import load_img, img_to_array

img = load_img('test.jpg', target_size=(200,200))
plt.imshow(img)
classes= ["apple","avacado","banana","cherry","nhan","orange","peach","pinapple","strawberry","grape"]

# %%
import numpy as np
imgRe = img_to_array(img)
imgRe = imgRe.reshape(1,200,200,3)  
imgRe = imgRe.astype('float32')
imgRe /= 255
y_pred = model.predict(imgRe)
print(y_pred)
y_classes = [np.argmax(element) for element in y_pred]
print(y_classes)
print(classes[y_classes[0]])
# Out:
# [[0.11319033 0.08323275 0.1020361  0.09313133 0.09290098 0.10730231
#   0.10691924 0.06993248 0.13329175 0.09806269]]
# [8]
# strawberry

# %%
plt.plot(history.history['accuracy'])
plt.title('Model accuracy')
plt.xlabel('epoch')
plt.legend(['Train', 'Validation'], loc='upper left')
plt.show()
